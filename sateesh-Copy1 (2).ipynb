# %%
    count=0
    for i in range(10):
        print_board(theboard)
        print("It's your turn "+turn+".\nWhich place you want to place")
        move=input()
        if theboard[move]!=' ':
            print("invalid position.theboard={
     '1':' ','2':' ','3':' ',
     '4':' ','5':' ','6':' ',
     '7':' ','8':' ','9':' ',
}
board_keys=[]
for i in theboard:
    board_keys.append(i)
def print_board(board):
    print(board['1']+'|'+board['2']+'|'+board['3'])
    print('-+-+-')
    print(board['4']+'|'+board['5']+'|'+board['6'])
    print('-+-+-')
    print(board['7']+'|'+board['8']+'|'+board['9'])



def game():
    turn='X'\n In which position you want to place?")
            continue
        else:
            theboard[move]=turn
            count+=1
        if count>4:
            if theboard['1']==theboard['2']==theboard['3']!=' ' :
                print('\n The Game over\n')
                print('Game won by player'+turn)
                break
            elif theboard['4']==theboard['5']==theboard['6']!=' ':
                  print('\n The Game over\n')
                  print('Game won by player'+turn)
                  break
            elif theboard['7']==theboard['8']==theboard['9']!=' ':
                  print('\n The Game over\n')
                  print('Game won by player'+turn)
                  break
            elif theboard['1']==theboard['4']==theboard['7']!=' ':
                  print('\n The Game over\n')
                  print('Game won by player'+turn)
                  break
            elif theboard['2']==theboard['5']==theboard['8']!=' ':
                  print('\n The Game over\n')
                  print('Game won by player'+turn)
                  break
            elif theboard['3']==theboard['6']==theboard['9']!=' ':
                  print('\n The Game over\n')
                  print('Game won by player'+turn)
                  break
            elif theboard['1']==theboard['5']==theboard['9']!=' ':
                  print('\n The Game over\n')
                  print('Game won by player'+turn)
                  break
            elif theboard['3']==theboard['5']==theboard['7']!=' ' :
                  print('\n The Game over\n')
                  print('Game won by player'+turn)
                  break
        if count==9:
            print('\n The Game over\n')
            print("The game is a tie")
            
        if turn=='X':
            turn='0'
        else:
            turn='X'
            
game()
# Out:
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# It's your turnX.
# Which place you want to place
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
def Go(n):
    if theboard[move]!=2:
            print("invalid position.\n In which position you want to place?")
            continue
    else:
            theboard[move]=n
            count+=1           
def posWin(X):
     for i in (1,4,7):
            if theboard[i]*theboard[i+1]*theboard[i+1]==18 or 50:
                 return i if theboard[i]==2 else i+1 if theboard[i+1]==2 else i+2
                 break
    for i in (1,2,3):
         if theboard[i]*theboard[i+3]*theboard[i+6]==18 or 50:
                 return i if theboard[i]==2 else i+3 if theboard[i+1]==2 else i+6
    for i in (1):
        if theboard[i]*theboard[i+4]*theboard[i+8]==18 or 50:
            return i if theboard[i]==2 else i+4 if theboard[i+4]==2 else i+8
    for i in (3):
        if theboard[i]*theboard[i+2]*theboard[i+4]==18 or 50:
            return i if theboard[i]==2 else i+2 if theboard[i+2]==2 else i+4

def game():
